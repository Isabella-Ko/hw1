# %%
from functools import reduce
# read into word_list 
f = open('dictionary.words.txt')
words_list = f.read().split('\n')
# print(words_list)

# new_words_list: sorted each letters in a word to match combinations of 16 letters
new_words_list = []
for i in words_list:
    new_i = sorted(i.upper())
    new_i = ''.join(new_i)
    new_words_list.append(new_i)
# print(new_words_list)

# Sorted words in the list - prepare for binary search
sort_nwl = sorted(new_words_list)

# input letters 
input_letters = input('unsolved_letters:')
a = sorted(input_letters.upper())
# print(a)

#Question 1: try to match all 16 letters
suggestions = []
# print(a)
def letter_16(a):
    for word in words_list:
        if a == sorted(word.upper()):
            suggestions.append(word)
#         else: 
#             print('no matches')
    print('suggestions for all 16 letters:', suggestions)
letter_16(a)

# get subsets 
from itertools import permutations, combinations

subsets = []
def substrings(input_letters):
    for i in range(len(input_letters)):
        for p in combinations(input_letters, i+1):
            p_string = ''.join(sorted(p))
            subsets.append(p_string)
#     print(subsets)
substrings(input_letters)

#binary search 
def bin_search(sort_nwl, sub):
    start = 0
    end = len(sort_nwl) - 1  
    
    while start <= end:
        middle = (start+end)//2  
        midpoint = sort_nwl[middle]
        
        if midpoint > sub:
            end = middle- 1
        elif midpoint < sub:
            start = middle + 1
        else:
            return midpoint
        
# match any subsets with the dictionary:
suggestions2 = []
def letter_any(subsets, sort_nwl):
    for sub in subsets: 
        match = bin_search(sort_nwl, sub)
        if match != None:  
            suggestions2.append(match)   
letter_any(subsets,sort_nwl)

#generate all matched words, and best recommendation to get highest scores. 
recom = []
for i in suggestions2: 
    index = new_words_list.index(i)
    real_words = words_list[index]
    recom.append(real_words)

# 'Qu'/'qu' matched set
qu_recom = []
for i in recom:
    if 'Qu' in i or 'qu'in i: 
        qu_recom.append(i)

# ranking 
ref = {'A':1,'B':1,'D':1,'E':1,'G':1,'I':1,'N':1,'O':1,'R':1,'S':1,'S':1,'T':1,'U':1,
      'C':2,'F':2,'H':2,'L':2,'M':2,'P':2,'V':2,'W':2,'Y':2,
      'J':3,'K':3,'Q':3,'X':3,'Z':3}   
        
#deal with 'Qu'/'qu'
if qu_recom != []:
    print('have Qu')
    scores = []
    for i in qu_recom:
        score = 0
        letter_lst = list(i.upper())
        score = reduce(lambda x, y: x+ref[y], letter_lst, 0)
        scores.append(score)

    index2 = scores.index(max(scores))
    su = qu_recom[index2]
    print('all matched words(include Qu): ', set(qu_recom))
    print('best suggestions: ', su)
else:
    scores = []
    for j in list(recom): 
        if j.count('U') == 1 or j.count('u') == 1:
            recom.remove(j)
        else:
            score = 0
            letter_lst = list(j.upper()) 
            score = reduce(lambda x, y: x+ref[y], letter_lst, 0)
            scores.append(score)

    index2 = scores.index(max(scores))
    su = recom[index2]
    print('all matched words: ', set(recom))
    print('best suggestions: ', su)
# Out:
# unsolved_letters:ADRJUIHZONOECMLM
# suggestions for all 16 letters: []
# all matched words:  {'Chi', 'zoom', 'Medan', 'Jaime', 'Maine', 'manhood', 'hailed', 'McMahon', 'commando', 'Mirzam', 'noodle', 'haze', 'ranch', 'income', 'minored', 'Ned', 'ion', 'Aden', 'clad', 'Mich', 'amid', 'zonal', 'jailor', 'decal', 'home', 'Homer', 'colder', 'Lenard', 'Alec', 'handier', 'Jon', 'clime', 'aide', 'craned', 'Ono', 'moored', 'ace', 'Cain', 'czar', 'Jedi', 'loomed', 'adze', 'arch', 'Hood', 'Delhi', 'larch', 'Eliza', 'Diane', 'machined', 'Lina', 'Nazi', 'mermaid', 'chromed', 'oho', 'rodeo', 'modal', 'dormice', 'Head', 'canoe', 'Coleman', 'Lance', 'hid', 'Media', 'lichen', 'Hale', 'remind', 'Monica', 'moronic', 'coda', 'Hera', 'indoor', 'mold', 'mend', 'camomile', 'commander', 'cooed', 'MCI', 'Daniel', 'Caroline', 'McDaniel', 'harem', 'claim', 'older', 'liner', 'Rachel', 'machine', 'child', 'mooch', 'caroled', 'Diem', 'Alden', 'milch', 'Leonor', 'Halon', 'Moore', 'Marion', 'memorial', 'hole', 'Major', 'horned', 'Ochoa', 'Cordelia', 'mailmen', 'domino', 'Jonah', 'loom', 'lam', 'Leo', 'dorm', 'hazed', 'ache', 'Leona', 'donor', 'hind', 'haloed', 'Alice', 'Richmond', 'charmed', 'helm', 'Mercado', 'arid', 'McLean', 'Mani', 'cod', 'moraine', 'Adler', 'romanced', 'jar', 'mime', 'Horne', 'anode', 'hod', 'hardline', 'Clair', 'Oneida', 'Elijah', 'hazier', 'Marlin', 'caldron', 'Carmine', 'Lane', 'Ora', 'Como', 'Nola', 'Mac', 'imam', 'Leonard', 'idler', 'micron', 'Dali', 'Mel', 'manic', 'meld', 'derail', 'medic', 'lamer', 'harmonized', 'hired', 'Lora', 'Reinhold', 'Arnhem', 'cholera', 'Neil', 'Leno', 'aeon', 'mica', 'cajoled', 'mil', 'Hal', 'Jain', 'dice', 'zinc', 'cooled', 'cad', 'Rhonda', 'Mon', 'canoed', 'Marine', 'Ariz', 'Cohen', 'roiled', 'hem', 'Jami', 'Odom', 'zero', 'Charmin', 'demon', 'claimed', 'menorah', 'maimed', 'cream', 'con', 'commoner', 'headroom', 'Lorenz', 'commend', 'Monera', 'arched', 'limn', 'Damien', 'Erna', 'aced', 'Miro', 'chord', 'Ron', 'lizard', 'melodic', 'coin', 'immoral', 'Moor', 'Mondale', 'ozone', 'moldier', 'Jodie', 'homier', 'Alonzo', 'Rommel', 'manlier', 'honored', 'Leonid', 'RCA', 'Marc', 'Eco', 'Jared', 'held', 'John', 'Drano', 'Aline', 'mohair', 'cornea', 'Johnie', 'condom', 'relic', 'Marconi', 'echo', 'colonizer', 'Carlin', 'Romano', 'Dinah', 'Jane', 'Charon', 'Calder', 'Dare', 'Jerald', 'Ezra', 'chamomile', 'Chad', 'Lord', 'old', 'lemon', 'Corina', 'herd', 'chid', 'amen', 'March', 'minced', 'Nordic', 'corneal', 'Malone', 'dolmen', 'Joe', 'randomize', 'Mirach', 'Liza', 'Eric', 'Dona', 'orchid', 'Han', 'Draco', 'Molina', 'Carole', 'Cline', 'rammed', 'heirloom', 'admire', 'caned', 'modem', 'Dior', 'door', 'lid', 'nicer', 'Moroni', 'clammier', 'Mao', 'damn', 'clod', 'normalized', 'Cadiz', 'calmed', 'loam', 'hoe', 'chained', 'crazed', 'maize', 'Lind', 'mimed', 'Lodz', 'Rio', 'had', 'colonize', 'deli', 'him', 'Morin', 'hie', 'Cairo', 'Henri', 'Zorn', 'Imelda', 'Eli', 'Claire', 'cinder', 'commode', 'Loren', 'Monaco', 'Dec', 'clone', 'Harmon', 'Laredo', 'Lima', 'Arline', 'common', 'zed', 'Rand', 'Mamore', 'core', 'Arno', 'mice', 'Roche', 'chlorine', 'MHz', 'Jed', 'demijohn', 'cameo', 'Lehman', 'condor', 'come', 'Damion', 'Emma', 'Amerind', 'chino', 'Ind', 'Lahore', 'modern', 'Mir', 'doorman', 'Moon', 'clamored', 'Moloch', 'dam', 'Del', 'Man', 'inhaled', 'Michael', 'doormen', 'aloe', 'chimed', 'homeland', 'Jamel', 'Darin', 'Clem', 'crammed', 'Milan', 'Ian', 'can', 'laze', 'arced', 'memo', 'honor', 'Meir', 'earldom', 'Oder', 'Inc', 'Charlie', 'harm', 'coo', 'Reinaldo', 'Indore', 'oriole', 'Mahdi', 'Hamlin', 'Elmo', 'chide', 'rid', 'Marne', 'Colon', 'zanier', 'Conrad', 'mom', 'Lorna', 'Deon', 'Erin', 'Lin', 'narc', 'acre', 'Aldrin', 'macron', 'homed', 'inhaler', 'recoil', 'comedian', 'Heinz', 'Rod', 'holed', 'colored', 'Chen', 'Orion', 'Elanor', 'hold', 'Marci', 'enrich', 'Moho', 'Handel', 'Dirac', 'rind', 'Dino', 'moorland', 'Zeno', 'harmonize', 'Mar', 'jailed', 'clamor', 'Marie', 'Delmar', 'hammer', 'dilemma', 'chloride', 'Dale', 'ached', 'mooched', 'chin', 'heroin', 'Racine', 'lore', 'Edam',  ...
# best suggestions:  chamomile

# %% [raw]
# p1 = document.getElementsByClassName("letter p1")
# p2 = document.getElementsByClassName("letter p2")
# p3 = document.getElementsByClassName("letter p3")
# p1 = Array.from(p1).map(x => x.innerText)
# p2 = Array.from(p2).map(x => x.innerText)
# p3 = Array.from(p3).map(x => x.innerText)
# p1.concat(p2).concat(p3).join("").toUpperCase()
